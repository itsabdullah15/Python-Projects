# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
urlnew= 'https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1'

# %%
response = requests.get(urlnew)
print(response)
if response.status_code == 200:
    print("Request successful")
else:
    print("Request failed")
# Out:
# <Response [200]>
# Request successful

# %%
soup = BeautifulSoup(r.text, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
for i in range(2,12):
    url = "https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i)
    r=requests.get(url)
    
    soup=BeautifulSoup(r.text, "lxml")
    box=soup.find("div",class_="_1YokD2 _3Mn1Gg")
#     print(soup)

#     np = soup.find("a",class_="_1LKTO3").get("href")
#     cnp = "https://www.flipkart.com"+np
#     print(cnp)

# %%
Product_name = []
Prices = []
Description = []
Reviews = []

for i in range(2,12):
    url = "https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i)
    r=requests.get(url)
    
    soup=BeautifulSoup(r.text, "lxml")
    box=soup.find("div",class_="_1YokD2 _3Mn1Gg")

    #Product_name
    pn = box.find_all("div",class_= "_4rR01T")
    # print(pn)
    for i in pn:
        pn = i.text
        Product_name.append(pn)
    print(Product_name)

    #prices
    p = box.find_all("div",class_="_30jeq3 _1_WHN1")

    for i in p:
        name = i.text
        Prices.append(name)
    print(Prices)


    # Description
    desc = box.find_all("ul",class_ ="_1xgFaf")

    for i in desc:
        name = i.text
        Description.append(name)
    print(Description)    

    # Reviews
    reviews = box.find_all("div",class_ ="_3LWZlK")

    for i in reviews:
        name = i.text
        Reviews.append(name)
    print(Reviews)
# Out:
# ['Xiaomi 12 Pro 5G (Noir Black, 256 GB)', 'IQOO 9T 5G (ALPHA, 128 GB)', 'OnePlus 9 5G (Winter Mist, 256 GB)', 'OnePlus 10T 5G (Moonstone Black, 256 GB)', 'Xiaomi 12 Pro 5G (Couture Blue, 256 GB)', 'Xiaomi 12 Pro 5G (Couture Blue, 256 GB)', 'SAMSUNG Galaxy S7 (Gold Platinum, 32 GB)', 'OnePlus 10T 5G (Jade Green, 256 GB)', 'IQOO 9T 5G (LEGEND, 128 GB)', 'APPLE iPhone 8 Plus (Gold, 64 GB)', 'OPPO Reno8 Pro 5G (Glazed Green, 256 GB)', 'IQOO 9 Pro 5G (Legend, 256 GB)', 'IQOO 9 Pro 5G (Dark Cruise, 256 GB)', 'APPLE iPhone 8 Plus (Space Grey, 64 GB)', 'OnePlus 9 Pro 5G (Morning Mist, 128 GB)', 'IQOO 9T 5G (LEGEND, 128 GB)', 'APPLE iPhone 8 Plus (Silver, 64 GB)', 'APPLE iPhone 11 (Black, 64 GB)', 'APPLE iPhone 11 (White, 64 GB)', 'vivo V27 Pro 5G (Noble Black, 256 GB)', 'SAMSUNG Galaxy A54 5G (Awesome Graphite, 256 GB)', 'vivo V27 Pro 5G (Magic Blue, 256 GB)', 'SAMSUNG Galaxy A54 5G (Awesome Violet, 256 GB)', 'SAMSUNG Galaxy A54 5G (Awesome Lime, 256 GB)']
# ...

# %%
print(len(Product_name))
print(len(Prices))
print(len(Description))
print(len(Reviews))
# Out:
# 240
# 240
# 240
# 232

# %%
df = pd.DataFrame.from_dict({"Product Name": Product_name, "Prices": Prices, "Description": Description, "Reviews": Reviews},orient='index')
# print(df)

# %%
df.to_csv("D:/Anaconda folder/ML/Web Scrapping/flipkart_mobiles_under_50000.csv")
